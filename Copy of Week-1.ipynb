# %% [markdown]
# # Week-1

# %% [markdown]
# ## How to accept a string as input from the user?

# %%
word = input()
print(word)

# %% [markdown]
# ## How to accept an integer as input from the user?

# %%
x = int(input())
print(x)

# %% [markdown]
# ## How to accept a real number as input from the user?

# %%
x = float(input())
print(x)

# %% [markdown]
# ## How to print multiple variables?

# %%
x = 10
y = 20
z = 30
print(x, y, z)

# %%
name = "Krishna"
age = 40
salary = 1.5
print(name, "is", age, "years old and earns", salary, "lpa")

# %% [markdown]
# ## How to print multiple objects on the same line separated by a comma?

# %%
print("this", "is", "good", sep=",")

# %%
print("this", "is", "good", sep="000")

# %% [markdown]
# ## How to print multiple objects on the same line without any separation between consecutive objects?

# %%
print("22", "f3", "001023", "@ds.study.iitm.ac.in", sep="")

# %% [markdown]
# ## How to print multiple sentences using a single string?

# %%
sentences = """this is sentence 1
this is sentence 2
this is sentence 3"""
print(sentences)

# %%
sentences = """this is sentence 1\nthis is sentence 2\nthis is sentence 3"""

# %%
x = "\n"
print(len(x))
# Out:
# 1

# %% [markdown]
# ## How to find the first and last letters in a word?

# %%
word = "first"
first = word[0]
last = word[-1]
print(first, last)

# %% [markdown]
# ## How to find the last three letters in a string?

# %%
sentence = "minus four"
sentence[-3:]

# %%
sentence = "minus four"
sentence[len(sentence) - 3 :]

# %% [markdown]
# ## How to extract the first four letters of a string?

# %%
sentence = "minus four"
sentence[:5]

# %% [markdown]
# ## How to extract a substring that excludes the first and last letters?

# %%
string = "maces"
sub = string[1:-1]
print(sub)
# Out:
# 'ace'

# %% [markdown]
# ## How to find if one string is a substring of another?

# %%
word_1 = "ace"
word_2 = "maces"
word_1 in word_2

# %% [markdown]
# ## How to string together multiple words into a sentence?

# %%
word_1 = "this"
word_2 = "statement"
word_3 = "is"
word_4 = "false"
space = " "
sentence = word_1 + space + word_2 + space + word_3 + space + word_4
print(sentence)

# %%
word_1 = "this"
word_2 = "statement"
word_3 = "is"
word_4 = "true"
sentence = f"{word_1} {word_2} {word_3} {word_4}"
sentence

# %%
year = 22
term = "f2"
roll = "001023"
domain = "ds.study.iitm.ac.in"
roll_number = f"{year}{term}{roll}@{domain}"
roll_number
# Out:
# '22f2001023@ds.study.iitm.ac.in'

# %% [markdown]
# ## How to replicate a string $n$ times?

# %%
word = "one"
n = 10
print(word * n)

# %% [markdown]
# ## How to reverse a string?

# %%
word = "123456789"
rev = word[::-1]
print(rev)

# %% [markdown]
# ## How to raise a number to a power?

# %%
x = 10
y = 3
x**y

# %%
x = 10
y = 3
pow(x, y)

# %% [markdown]
# ## How to compute the square root of a number?

# %%
x = 4
print(x**0.5)

# %% [markdown]
# ## How to find the quotient and remainder when a number is divided by another?

# %%
x = 17
y = 3
q = x // y
r = x % y
print(f"when {x} is divided by {y}, the quotient is {q} and the remainder is {r}")
# Out:
# when 17 is divided by 3, the quotient is 5 and the remainder is 2

# %% [markdown]
# ## How to find the integer part of a decimal number?

# %%
x = 12.345
print(int(x))
# Out:
# 12

# %% [markdown]
# ## How to find the fractional part of a positive decimal number?

# %%
x = 12.34567
print(x - int(x))
# Out:
# 12.35
# 12

# %% [markdown]
# ## How to round off a number to two decimal places?

# %%
x = 12.3456
print(round(x, 2))

# %%
x = 12.3456
print(f"{x:.2f}")

# %% [markdown]
# ## How to find the absolute value of a number?

# %%
x = -123
print(abs(x))

# %% [markdown]
# ## How to express a decimal number as a rational number, that is, in the form $p / q$?

# %%
x = 0.25
print(x.as_integer_ratio())
# Out:
# (1, 4)

# %% [markdown]
# ## How to find the number of characters in a word?

# %%
word = "abcd"
print(len(word))

# %% [markdown]
# ## How to swap the values in two variables?

# %%
x = 10
y = 20
x, y = y, x
print(x)
print(y)

# %% [markdown]
# ## How to find the type of a variable?

# %%
x = 12.34
print(type(x))
# Out:
# float

# %% [markdown]
# ## How to find the sum of all the digits in a three-digit number?

# %%
x = "123"
print(int(x[0]) + int(x[1]) + int(x[2]))
# Out:
# 6

# %% [markdown]
# ## How to convert a string to lower or upper case?

# %%
word = "good"
word = word.upper()
print(word)

# %%
word = "GOOD"
word = word.lower()
print(word)

# %% [markdown]
# ## How to count the number of times a particular character appears in a string?

# %%
word = "abbcdeb"
char = "b"
print(word.count(char))

# %%
word = "abcabcabc"
sub = "abc"
print(word.count(sub))

# %% [markdown]
# ## How to replace a particular character from a string?

# %%
word = "g00d"
word = word.replace("0", "o")
print(word)

# %% [markdown]
# ## How to capitalize a string?

# %%
name = "krishna"
name = name.capitalize()
print(name)

# %% [markdown]
# ## How to check if a string is in upper or lower case?

# %%
word = "good"
print(word.isupper())
print(word.islower())

# %% [markdown]
# ## How to check if a string has only letters?

# %%
word = "good"
print(word.isalpha())

# %% [markdown]
# ## How to check if a string has only numbers?

# %%
word = "1234"
print(word.isdigit())

# %% [markdown]
# ## How to check if a string has only letters or numbers?

# %%
word = "123abc"
print(word.isalnum())

# %% [markdown]
# ## How to find the index of a character in a string?

# %%
word = "abcd"
print(word.index("b"))

# %%
word = "abcdb"
print(word.find("b"))
# Out:
# 1

# %% [markdown]
# ## How to remove whitespaces from the beginning and end of a string?

# %%
word = "\n\n krishna \n\n"
print(word)
word = word.strip()
print(word)

# %% [markdown]
# ## How to check if a string ends with some substring?

# %% [markdown]
# word = "coming"
# ends = "ming"
# print(word[-len(ends) :] == ends)

# %%
word = "coming"
ends = "ing"
print(word.endswith(ends))

# %% [markdown]
# ## How to check which of two strings comes first in alphabetical order?

# %%
word_1 = "easy"
word_2 = "easily"
print(word_1 < word_2)

# %% [markdown]
# ## How to find the maximum among three numbers?

# %%
x = 10
y = 20
z = 30
print(max(x, y, z))

# %% [markdown]
# ## How to evaluate the expression $e^{\pi} + \pi^{e}$?

# %%
import math

print(math.e**math.pi + math.pi**math.e)

# %% [markdown]
# ## How to generate a random integer between 1 and 10?

# %%
import random

print(random.randint(1, 2))

# %% [markdown]
# ## Working with JSON files in python

# %%
import json

# %%
with open('/content/sample_data/anscombe.json', 'r') as infile:
    y = json.loads(infile)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-043436abc050> in <cell line: 1>()
#       1 with open('/content/sample_data/anscombe.json', 'r') as infile:
# ----> 2     y = json.loads(infile)
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337     else:
#     338         if not isinstance(s, (bytes, bytearray)):
# --> 339             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                             f'not {s.__class__.__name__}')
#     341         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not TextIOWrapper
