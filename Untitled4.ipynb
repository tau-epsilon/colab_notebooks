# %%
import random
import time
def simulate_bus_speed(self, duration):
        # Speed in kilometers per hour
        speed = 0
        max_speed = 60
        time_step = 1  # Time step in seconds

        sum_of_speed = 0
        for _ in range(duration):
            # Generate random acceleration or deceleration
            acceleration = random.gauss(0, 2)  # Random acceleration/deceleration between -2 and 2 km/h per second
            acceleration*=2

            # Ensure speed stays within limits
            speed = max(0, min(max_speed, speed + acceleration))

            print(f"Bus Speed: {speed:.3f} km/h")
            time.sleep(time_step)
            sum_of_speed += speed
        average_speed = sum_of_speed/duration
        return average_speed
simulate_bus_speed('Bus', 60)
# Out:
# Bus Speed: 0.000 km/h
# Bus Speed: 0.539 km/h
# Bus Speed: 0.641 km/h
# Bus Speed: 0.000 km/h
# Bus Speed: 0.000 km/h
# Bus Speed: 0.000 km/h
# Bus Speed: 1.932 km/h
# Bus Speed: 0.000 km/h
# Bus Speed: 2.563 km/h
# Bus Speed: 5.688 km/h
# Bus Speed: 8.171 km/h
# Bus Speed: 5.594 km/h
# Bus Speed: 3.325 km/h
# Bus Speed: 1.815 km/h
# Bus Speed: 2.528 km/h
# Bus Speed: 2.524 km/h
# Bus Speed: 1.656 km/h
# Bus Speed: 0.000 km/h
# Bus Speed: 6.609 km/h
# Bus Speed: 6.394 km/h
# Bus Speed: 0.585 km/h
# Bus Speed: 7.532 km/h
# Bus Speed: 0.000 km/h
# Bus Speed: 2.468 km/h
# Bus Speed: 4.404 km/h
# Bus Speed: 7.685 km/h
# Bus Speed: 3.805 km/h
# Bus Speed: 6.686 km/h
# Bus Speed: 5.035 km/h
# Bus Speed: 3.171 km/h
# Bus Speed: 0.338 km/h
# Bus Speed: 9.321 km/h
# Bus Speed: 12.168 km/h
# Bus Speed: 13.611 km/h
# Bus Speed: 6.877 km/h
# Bus Speed: 0.660 km/h
# Bus Speed: 4.503 km/h
# Bus Speed: 5.681 km/h
# Bus Speed: 2.115 km/h
# Bus Speed: 4.463 km/h
# Bus Speed: 5.759 km/h
# Bus Speed: 2.594 km/h
# Bus Speed: 7.103 km/h
# Bus Speed: 11.583 km/h
# Bus Speed: 8.453 km/h
# Bus Speed: 3.363 km/h
# Bus Speed: 1.037 km/h
# Bus Speed: 0.000 km/h
# Bus Speed: 4.689 km/h
# Bus Speed: 2.606 km/h
# Bus Speed: 0.000 km/h
# Bus Speed: 3.986 km/h
# Bus Speed: 2.041 km/h
# Bus Speed: 5.388 km/h
# Bus Speed: 1.251 km/h
# Bus Speed: 0.139 km/h
# Bus Speed: 0.000 km/h
# Bus Speed: 0.000 km/h
# Bus Speed: 0.000 km/h
# Bus Speed: 0.000 km/h
# 3.517982670814318
